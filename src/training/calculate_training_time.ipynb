# %%
current_epoch = 97
total_epochs = 247
time_per_epoch = 19  # in seconds

epochs_remaining = total_epochs - current_epoch
time_left_hours = (epochs_remaining * time_per_epoch) / 3600
time_left_mins = (epochs_remaining * time_per_epoch) / 60

print(f"Time left for training: {time_left_hours:.2f} hours ({time_left_mins:.2f} minutes)")
# Out:
# Time left for training: 0.79 hours (47.50 minutes)
